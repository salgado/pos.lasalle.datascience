# %%
idade = 10

if idade<16:
  print("nao pode votar")
else:
  print("pode votar")
# Out:
# nao pode votar

# %%
x = 100
if x < 16:
  print('não pode votar')
elif x > 15 and x < 18:
  print('voto opcional')
elif x > 17 and x < 70: 
  print('voto obrigatório')
else:
  print('voto opcional')
# Out:
# voto opcional

# %%
#arquivo_csv="https://dadosabertos.bndes.gov.br/dataset/c5dce03d-7ad1-4149-8803-2ee082f9fcbc/resource/2eede8ef-ec42-46f7-a088-e40bddd046f1/download/mr1.csv"
arquivo_csv="https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv"

# %%
import pandas as pd
dados = pd.read_csv(arquivo_csv,",")

# %%
dados['Sex']
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 882      male
# 883    female
# 884    female
# 885      male
# 886      male
# Name: Sex, Length: 887, dtype: object

# %%
dados.head(10)
# Out:
#    Survived  Pclass  ... Parents/Children Aboard     Fare
# 0         0       3  ...                       0   7.2500
# 1         1       1  ...                       0  71.2833
# 2         1       3  ...                       0   7.9250
# 3         1       1  ...                       0  53.1000
# 4         0       3  ...                       0   8.0500
# 5         0       3  ...                       0   8.4583
# 6         0       1  ...                       0  51.8625
# 7         0       3  ...                       1  21.0750
# 8         1       3  ...                       2  11.1333
# 9         1       2  ...                       0  30.0708
#
# [10 rows x 8 columns]

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Survived                 887 non-null    int64
#  1   Pclass                   887 non-null    int64
#  2   Name                     887 non-null    object
#  3   Sex                      887 non-null    object
#  4   Age                      887 non-null    float64
#  5   Siblings/Spouses Aboard  887 non-null    int64
#  6   Parents/Children Aboard  887 non-null    int64
#  7   Fare                     887 non-null    float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.6+ KB

# %%
dados.describe()
# Out:
#          Survived      Pclass  ...  Parents/Children Aboard       Fare
# count  887.000000  887.000000  ...               887.000000  887.00000
# mean     0.385569    2.305524  ...                 0.383315   32.30542
# std      0.487004    0.836662  ...                 0.807466   49.78204
# min      0.000000    1.000000  ...                 0.000000    0.00000
# 25%      0.000000    2.000000  ...                 0.000000    7.92500
# 50%      0.000000    3.000000  ...                 0.000000   14.45420
# 75%      1.000000    3.000000  ...                 0.000000   31.13750
# max      1.000000    3.000000  ...                 6.000000  512.32920
#
# [8 rows x 6 columns]

# %%
dados[ (dados['Survived'] == 1)][dados['Age'] >= 30].describe()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#        Survived      Pclass  ...  Parents/Children Aboard        Fare
# count     155.0  155.000000  ...               155.000000  155.000000
# mean        1.0    1.561290  ...                 0.303226   64.045135
# std         0.0    0.756649  ...                 0.687308   79.811591
# min         1.0    1.000000  ...                 0.000000    7.229200
# 25%         1.0    1.000000  ...                 0.000000   19.875000
# 50%         1.0    1.000000  ...                 0.000000   35.500000
# 75%         1.0    2.000000  ...                 0.000000   79.825000
# max         1.0    3.000000  ...                 5.000000  512.329200
#
# [8 rows x 6 columns]

# %%
dados[ (dados['Survived'] == 1)][dados['Fare'] >= 500]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#      Survived  Pclass  ... Parents/Children Aboard      Fare
# 257         1       1  ...                       0  512.3292
# 676         1       1  ...                       1  512.3292
# 733         1       1  ...                       0  512.3292
#
# [3 rows x 8 columns]

# %%
mulheres_total = dados[ dados['Sex'] == 'female' ]
mulheres_total
# Out:
#      Survived  Pclass  ... Parents/Children Aboard     Fare
# 1           1       1  ...                       0  71.2833
# 2           1       3  ...                       0   7.9250
# 3           1       1  ...                       0  53.1000
# 8           1       3  ...                       2  11.1333
# 9           1       2  ...                       0  30.0708
# ..        ...     ...  ...                     ...      ...
# 876         1       2  ...                       1  26.0000
# 878         0       3  ...                       0  10.5167
# 881         0       3  ...                       5  29.1250
# 883         1       1  ...                       0  30.0000
# 884         0       3  ...                       2  23.4500
#
# [314 rows x 8 columns]

# %%
mulheres_total[mulheres_total['Survived'] == 1]
# Out:
#      Survived  Pclass  ... Parents/Children Aboard     Fare
# 1           1       1  ...                       0  71.2833
# 2           1       3  ...                       0   7.9250
# 3           1       1  ...                       0  53.1000
# 8           1       3  ...                       2  11.1333
# 9           1       2  ...                       0  30.0708
# ..        ...     ...  ...                     ...      ...
# 870         1       2  ...                       0  24.0000
# 871         1       3  ...                       0   7.2250
# 875         1       1  ...                       1  83.1583
# 876         1       2  ...                       1  26.0000
# 883         1       1  ...                       0  30.0000
#
# [233 rows x 8 columns]

# %%
print(233/314)
# Out:
# 0.7420382165605095

# %%
mulheres_total.plot.hist()

# %%
mulheres_total
# Out:
#      Survived  Pclass  ... Parents/Children Aboard     Fare
# 1           1       1  ...                       0  71.2833
# 2           1       3  ...                       0   7.9250
# 3           1       1  ...                       0  53.1000
# 8           1       3  ...                       2  11.1333
# 9           1       2  ...                       0  30.0708
# ..        ...     ...  ...                     ...      ...
# 876         1       2  ...                       1  26.0000
# 878         0       3  ...                       0  10.5167
# 881         0       3  ...                       5  29.1250
# 883         1       1  ...                       0  30.0000
# 884         0       3  ...                       2  23.4500
#
# [314 rows x 8 columns]

# %%
california = pd.read_csv("sample_data/california_housing_test.csv")

# %%
california
# Out:
#       longitude  latitude  ...  median_income  median_house_value
# 0       -122.05     37.37  ...         6.6085            344700.0
# 1       -118.30     34.26  ...         3.5990            176500.0
# 2       -117.81     33.78  ...         5.7934            270500.0
# 3       -118.36     33.82  ...         6.1359            330000.0
# 4       -119.67     36.33  ...         2.9375             81700.0
# ...         ...       ...  ...            ...                 ...
# 2995    -119.86     34.42  ...         1.1790            225000.0
# 2996    -118.14     34.06  ...         3.3906            237200.0
# 2997    -119.70     36.30  ...         2.2895             62000.0
# 2998    -117.12     34.10  ...         3.2708            162500.0
# 2999    -119.63     34.42  ...         8.5608            500001.0
#
# [3000 rows x 9 columns]

# %%
california.describe()
# Out:
#          longitude    latitude  ...  median_income  median_house_value
# count  3000.000000  3000.00000  ...    3000.000000          3000.00000
# mean   -119.589200    35.63539  ...       3.807272        205846.27500
# std       1.994936     2.12967  ...       1.854512        113119.68747
# min    -124.180000    32.56000  ...       0.499900         22500.00000
# 25%    -121.810000    33.93000  ...       2.544000        121200.00000
# 50%    -118.485000    34.27000  ...       3.487150        177650.00000
# 75%    -118.020000    37.69000  ...       4.656475        263975.00000
# max    -114.490000    41.92000  ...      15.000100        500001.00000
#
# [8 rows x 9 columns]
